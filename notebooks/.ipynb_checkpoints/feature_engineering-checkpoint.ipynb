# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd 
import numpy as np 
import os
import sys

# Get the absolute path to the 'util' directory (assuming 'eda.ipynb' is one level down from 'your_project')
data_dir = os.path.abspath(os.path.join('Documents/CaliforniaWildfireAnalysis', 'data'))

# Add the 'util' directory to sys.path if it's not already there
if data_dir not in sys.path:
    sys.path.append(data_dir)
data_dir
# Out:
# '/Users/shireen/Documents/CaliforniaWildfireAnalysis/data'

# %%
df = pd.read_csv(data_dir+'/supervised_leaned_eda.csv')
df.head()
# Out:
#    ZIP Code  Cov A Amount Weighted Avg  Avg Fire Risk Score  \
# 0     90001                  261658.94                 0.32
# 1     90002                  250804.27                 0.33
# 2     90003                  266381.48                 0.31
# 3     90004                  929430.46                 0.45
# 4     90005                 1329088.35                 0.44
#
#    Number of Negligible Fire Risk Exposure  Number of Low Fire Risk Exposure  \
# 0                                      884                               407
# 1                                     1270                               614
# 2                                     1195                               535
# 3                                      962                               643
# 4                                      224                               127
#
#    Number of Moderate Fire Risk Exposure  Number of High Fire Risk Exposure  \
# 0                                      0                                  0
# 1                                      0                                  0
# 2                                      1                                  0
# 3                                     56                                  0
# 4                                     16                                  0
#
#    Number of Very High Fire Risk Exposure  Earned Premium 2020  \
# 0                                       0               982193
# 1                                       0              1400005
# 2                                       0              1424103
# 3                                       0              3992219
# 4                                       0              1263229
#
#    Earned Exposure 2020  Non-CAT Cov A Fire - Incurred Losses  \
# 0                  1291                                 96882
# 1                  1884                                 45212
# 2                  1731                                449601
# 3                  1661                                  7635
# 4                   368                                  1383
#
#    Non-CAT Cov A Smoke - Incurred Losses  \
# 0                                   9320
# 1                                   1686
# 2                                      0
# 3                                      0
# 4                                      0
#
#    Non-CAT Cov A Smoke - Number of Claims  \
# 0                                       1
# 1                                       1
# 2                                       0
# 3                                       0
# 4                                       0
#
#    Non-CAT Cov C Fire - Number of Claims  \
# 0                                      1
# 1                                      1
# 2                                      2
# 3                                      0
# 4                                      0
#
#    Non-CAT Cov C Smoke - Incurred Losses  CAT Cov A Smoke - Number of Claims  \
# 0                                   5070                                  13
# 1                                    542                                   5
# 2                                      0                                   6
# 3                                      0                                   1
# 4                                      0                                   0
#
#    CAT Cov C Fire - Incurred Losses  CAT Cov C Smoke - Incurred Losses  \
# 0                                 0                                  0
# 1                              3582                                  0
# 2                              6800                                223
# 3                                 0                                384
# 4                                 0                                  0
#
#    Earned Premium 2021  Earned Exposure 2021
# 0              1076066                  1345
# 1              1523488                  1939
# 2              1537173                  1769
# 3              4428387                  1675
# 4              1377640                   379

# %%
df["Total CAT Losses"] = df["CAT Cov C Fire - Incurred Losses"]+ df["CAT Cov C Smoke - Incurred Losses"]
df["Total Non-CAT Losses"] = df["Non-CAT Cov A Fire - Incurred Losses"] + df["Non-CAT Cov A Smoke - Incurred Losses"]
df.rename(columns = { "CAT Cov A Smoke - Number of Claims":"Total CAT Claims"}, inplace= True)
df["Total Non-CAT Claims"] = df["Non-CAT Cov A Smoke - Number of Claims"]+df["Non-CAT Cov C Fire - Number of Claims"]

# %%
df.columns
# Out:
# Index(['ZIP Code', 'Cov A Amount Weighted Avg', 'Avg Fire Risk Score',
#        'Number of Negligible Fire Risk Exposure',
#        'Number of Low Fire Risk Exposure',
#        'Number of Moderate Fire Risk Exposure',
#        'Number of High Fire Risk Exposure',
#        'Number of Very High Fire Risk Exposure', 'Earned Premium 2020',
#        'Earned Exposure 2020', 'Non-CAT Cov A Fire - Incurred Losses',
#        'Non-CAT Cov A Smoke - Incurred Losses',
#        'Non-CAT Cov A Smoke - Number of Claims',
#        'Non-CAT Cov C Fire - Number of Claims',
#        'Non-CAT Cov C Smoke - Incurred Losses', 'Total CAT Claims',
#        'CAT Cov C Fire - Incurred Losses', 'CAT Cov C Smoke - Incurred Losses',
#        'Earned Premium 2021', 'Earned Exposure 2021', 'Total CAT Losses',
#        'Total Non-CAT Losses', 'Total Non-CAT Claims'],
#       dtype='object')

# %%
df['Avg Premium'] = df['Earned Premium 2020'] / df['Earned Exposure 2020'].replace(0, np.nan)
df['Avg CAT Loss'] = df['Total CAT Losses'] / df['Earned Exposure 2020'].replace(0, np.nan)
df['Avg Non-CAT Loss'] = df['Total Non-CAT Losses'] / df['Earned Exposure 2020'].replace(0, np.nan)
df['Avg CAT Claims'] = df['Total Non-CAT Claims'] / df['Earned Exposure 2020'].replace(0, np.nan)
df['Avg Non-CAT Claims'] = df['Total CAT Claims'] / df['Earned Exposure 2020'].replace(0, np.nan)
df['Avg Premium 2021'] = df['Earned Premium 2021'] / df['Earned Exposure 2021'].replace(0, np.nan)
df['Loss Ratio'] = (df['Total CAT Losses'] + df['Total Non-CAT Losses'])/df['Earned Premium 2020'].replace(0, np.nan)
df['Claim Frequency'] = (df['Total Non-CAT Claims']+df['Total CAT Claims'])/df['Earned Exposure 2020'].replace(0, np.nan)
df['Average Claim Severity'] = (df['Total CAT Losses'] + df['Total Non-CAT Losses'])/(df['Total Non-CAT Claims']+df['Total CAT Claims']).replace(0, np.nan)
# Replace inf with NaN, then drop all NaN values
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)

# %%
df["Avg Fire Risk Score"]=df["Avg Fire Risk Score"].round(0)
df.head()
# Out:
#    ZIP Code  Cov A Amount Weighted Avg  Avg Fire Risk Score  \
# 0     90001                  261658.94                  0.0
# 1     90002                  250804.27                  0.0
# 2     90003                  266381.48                  0.0
# 3     90004                  929430.46                  0.0
# 5     90006                  463506.41                  0.0
#
#    Number of Negligible Fire Risk Exposure  Number of Low Fire Risk Exposure  \
# 0                                      884                               407
# 1                                     1270                               614
# 2                                     1195                               535
# 3                                      962                               643
# 5                                      220                               121
#
#    Number of Moderate Fire Risk Exposure  Number of High Fire Risk Exposure  \
# 0                                      0                                  0
# 1                                      0                                  0
# 2                                      1                                  0
# 3                                     56                                  0
# 5                                      1                                  0
#
#    Number of Very High Fire Risk Exposure  Earned Premium 2020  \
# 0                                       0               982193
# 1                                       0              1400005
# 2                                       0              1424103
# 3                                       0              3992219
# 5                                       0               428828
#
#    Earned Exposure 2020  ...  Total Non-CAT Claims  Avg Premium  Avg CAT Loss  \
# 0                  1291  ...                     2   760.800155      0.000000
# 1                  1884  ...                     2   743.102442      1.901274
# 2                  1731  ...                     2   822.705373      4.057192
# 3                  1661  ...                     0  2403.503311      0.231186
# 5                   341  ...                     3  1257.560117     50.466276
#
#    Avg Non-CAT Loss  Avg CAT Claims  Avg Non-CAT Claims  Avg Premium 2021  \
# 0         82.263362        0.001549            0.010070        800.049071
# 1         24.892781        0.001062            0.002654        785.708097
# 2        259.734835        0.001155            0.003466        868.950254
# 3          4.596629        0.000000            0.000602       2643.813134
# 5       1989.835777        0.008798            0.000000       1346.379888
#
#    Loss Ratio  Claim Frequency  Average Claim Severity
# 0    0.108127         0.011619             7080.133333
# 1    0.036057         0.003715             7211.428571
# 2    0.320640         0.004622            57078.000000
# 3    0.002009         0.000602             8019.000000
# 5    1.622429         0.008798           231914.333333
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Feature Selection

# %%
features_to_drop = highly_correlated_features(df, "Avg Premium 2021")
features_to_drop
# Out:
# Earned Premium 2021 Earned Premium 2020 0.41757028276857755 0.41468378313595666
# Earned Exposure 2021 Earned Exposure 2020 -0.09890894481438185 -0.10070738049346405
# Total CAT Losses CAT Cov C Fire - Incurred Losses 0.05545515574255816 0.055716213983149646
# Total Non-CAT Losses Non-CAT Cov A Fire - Incurred Losses 0.02983168788832289 0.03449523821271344
# Total Non-CAT Claims Non-CAT Cov A Smoke - Number of Claims -0.09684074505245295 -0.07702126748121653
# Avg CAT Claims Avg Non-CAT Loss 0.011259768267982237 0.04246210908048559
# ['Earned Premium 2021',
#  'Earned Exposure 2021',
#  'CAT Cov C Fire - Incurred Losses',
#  'Non-CAT Cov A Fire - Incurred Losses',
#  'Non-CAT Cov A Smoke - Number of Claims',
#  'Avg Non-CAT Loss']

# %% [markdown]
# Observation:
#
# <strong> Engineered features have groups of high correlation </strong>
#
# Impact:
# 'Earned Premium 2021',
# 'Earned Exposure 2021',
# 'CAT Cov C Fire - Incurred Losses',
# 'Non-CAT Cov A Fire - Incurred Losses',
# 'Non-CAT Cov A Smoke - Number of Claims',
# 'Avg Non-CAT Loss' are dropped from the features list due to belonging to a high correlation se

# %%
features_to_remove = ["Avg Non-CAT Loss", "Non-CAT Cov A Smoke - Number of Claims",
                      "Non-CAT Cov A Fire - Incurred Losses","CAT Cov C Fire - Incurred Losses","Earned Exposure 2021","Earned Premium 2021"]
filtered_df=df.drop(columns=features_to_remove)
filtered_df.head()
# Out:
#    ZIP Code  Cov A Amount Weighted Avg  Avg Fire Risk Score  \
# 0     90001                  261658.94                  0.0
# 1     90002                  250804.27                  0.0
# 2     90003                  266381.48                  0.0
# 3     90004                  929430.46                  0.0
# 5     90006                  463506.41                  0.0
#
#    Number of Negligible Fire Risk Exposure  Number of Low Fire Risk Exposure  \
# 0                                      884                               407
# 1                                     1270                               614
# 2                                     1195                               535
# 3                                      962                               643
# 5                                      220                               121
#
#    Number of Moderate Fire Risk Exposure  Number of High Fire Risk Exposure  \
# 0                                      0                                  0
# 1                                      0                                  0
# 2                                      1                                  0
# 3                                     56                                  0
# 5                                      1                                  0
#
#    Number of Very High Fire Risk Exposure  Earned Premium 2020  \
# 0                                       0               982193
# 1                                       0              1400005
# 2                                       0              1424103
# 3                                       0              3992219
# 5                                       0               428828
#
#    Earned Exposure 2020  ...  Total Non-CAT Losses  Total Non-CAT Claims  \
# 0                  1291  ...                106202                     2
# 1                  1884  ...                 46898                     2
# 2                  1731  ...                449601                     2
# 3                  1661  ...                  7635                     0
# 5                   341  ...                678534                     3
#
#    Avg Premium  Avg CAT Loss  Avg CAT Claims  Avg Non-CAT Claims  \
# 0   760.800155      0.000000        0.001549            0.010070
# 1   743.102442      1.901274        0.001062            0.002654
# 2   822.705373      4.057192        0.001155            0.003466
# 3  2403.503311      0.231186        0.000000            0.000602
# 5  1257.560117     50.466276        0.008798            0.000000
#
#    Avg Premium 2021  Loss Ratio  Claim Frequency  Average Claim Severity
# 0        800.049071    0.108127         0.011619             7080.133333
# 1        785.708097    0.036057         0.003715             7211.428571
# 2        868.950254    0.320640         0.004622            57078.000000
# 3       2643.813134    0.002009         0.000602             8019.000000
# 5       1346.379888    1.622429         0.008798           231914.333333
#
# [5 rows x 26 columns]

# %% [markdown]
# ## EDA for Remaining Engineered Features

# %%
import ppscore
import pandas as pd
data = df.select(["Average Claim Severity", "Avg Premium 2021"])
# Out:
# ---------------------------------------------------------------------------
# ContextualVersionConflict                 Traceback (most recent call last)
# Cell In[269], line 1
# ----> 1 import ppscore
#       2 import pandas as pd
#       3 data = df.select(["Average Claim Severity", "Avg Premium 2021"])
#
# File /opt/anaconda3/lib/python3.12/site-packages/ppscore/__init__.py:7
#       4 try:
#       5     # Change here if project is renamed and does not equal the package name
#       6     dist_name = __name__
# ----> 7     __version__ = get_distribution(dist_name).version
#       8 except DistributionNotFound:  # pragma: no cover
#       9     __version__ = "unknown"
#
# File /opt/anaconda3/lib/python3.12/site-packages/pkg_resources/__init__.py:497, in get_distribution(dist)
#     495     dist = Requirement.parse(dist)
#     496 if isinstance(dist, Requirement):
# --> 497     dist = get_provider(dist)
#     498 if not isinstance(dist, Distribution):
#     499     raise TypeError("Expected string, Requirement, or Distribution", dist)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pkg_resources/__init__.py:384, in get_provider(moduleOrReq)
#     382 """Return an IResourceProvider for the named module or requirement"""
#     383 if isinstance(moduleOrReq, Requirement):
# --> 384     return working_set.find(moduleOrReq) or require(str(moduleOrReq))[0]
#     385 try:
#     386     module = sys.modules[moduleOrReq]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pkg_resources/__init__.py:937, in WorkingSet.require(self, *requirements)
#     928 def require(self, *requirements):
#     929     """Ensure that distributions matching `requirements` are activated
#     930
#     931     `requirements` must be a string or a (possibly-nested) sequence
#    (...)
#     935     included, even if they were already activated in this working set.
#     936     """
# --> 937     needed = self.resolve(parse_requirements(requirements))
#     939     for dist in needed:
#     940         self.add(dist)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pkg_resources/__init__.py:798, in WorkingSet.resolve(self, requirements, env, installer, replace_conflicting, extras)
#     795 if not req_extras.markers_pass(req, extras):
#     796     continue
# --> 798 dist = self._resolve_dist(
#     799     req, best, replace_conflicting, env, installer, required_by, to_activate
#     800 )
#     802 # push the new requirements onto the stack
#     803 new_requirements = dist.requires(req.extras)[::-1]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pkg_resources/__init__.py:844, in WorkingSet._resolve_dist(self, req, best, replace_conflicting, env, installer, required_by, to_activate)
#     841 if dist not in req:
#     842     # Oops, the "best" so far conflicts with a dependency
#     843     dependent_req = required_by[req]
# --> 844     raise VersionConflict(dist, req).with_context(dependent_req)
#     845 return dist
#
# ContextualVersionConflict: (pandas 2.2.2 (/opt/anaconda3/lib/python3.12/site-packages), Requirement.parse('pandas<2.0.0,>=1.0.0'), {'ppscore'})
